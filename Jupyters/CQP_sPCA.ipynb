# %%
import numpy as np
from time import process_time
from scipy.io import loadmat
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.svm import NuSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import f1_score
from sklearn import metrics
from sklearn.linear_model import Ridge

import warnings
warnings.filterwarnings("ignore")

N = 4

pd = '' #path with data

# %%
data = loadmat(pd+'dataAnswer_regular_from_0_to_3pion4.mat')
answers_reg_ = np.transpose(np.array(data['answers']))
data = loadmat(pd+'dataChoi3_sn_regular_from_0_to_3pion4.mat')
chois_reg_ = np.array(data['choi'])

data = loadmat(pd+'dataAnswer_regular_otherY_from_0_to_3pion4.mat')
answers_Y = np.transpose(np.array(data['answers']))
data = loadmat(pd+'dataChoi3_sn_regular_otherY_from_0_to_3pion4.mat')
chois_Y = np.array(data['choi'])

chois_short = np.concatenate((chois_reg_, chois_Y), axis=0)
answers_reg = np.concatenate((answers_reg_, answers_Y), axis=0)


data = loadmat(pd+'dataChoi3_regular_from_0_to_3pion4.mat')
chois_reg_ = np.array(data['choi'])
data = loadmat(pd+'dataChoi3_regular_otherY_from_0_to_3pion4.mat')
chois_Y = np.array(data['choi'])

chois_long = np.concatenate((chois_reg_, chois_Y), axis=0)

data = loadmat(pd+'dataAnswer_regular_3pion8.mat')
answers_other1 = np.transpose(np.array(data['answers']))
data = loadmat(pd+'dataChoi3_sn_regular_3pion8.mat')
chois_other1 = np.array(data['choi'])

data = loadmat(pd+'dataAnswer_regular_otherY_3pion8.mat')
answers_other2 = np.transpose(np.array(data['answers']))
data = loadmat(pd+'dataChoi3_sn_regular_otherY_3pion8.mat')
chois_other2 = np.array(data['choi'])

chois_short_other = np.concatenate((chois_other1, chois_other2), axis=0)
answers_other = np.concatenate((answers_other1, answers_other2), axis=0)


data = loadmat(pd+'dataChoi3_regular_3pion8.mat')
chois_other1 = np.array(data['choi'])
data = loadmat(pd+'dataChoi3_regular_otherY_3pion8.mat')
chois_other2 = np.array(data['choi'])

chois_long_other = np.concatenate((chois_other1, chois_other2), axis=0)

# %%
X = chois_long
y = answers_reg

# %%
names = [
    "Nearest Neighbors", 
    "Linear SVM       ",
    "Poly SVM         ",
    #"sigmoid SVM      ",
    #"RBF SVM          ", 
    "Decision Tree    ",
    "Random Forest    ",
    "Neural Net       ",
    "AdaBoost         ",
    "Naive Bayes      ",
    "LDA              ",
    "QDA              "
    ]

classifiers = [ 
    KNeighborsClassifier(3),
    SVC(kernel="linear"),
    SVC(kernel="poly", degree=3),
    #SVC(kernel="sigmoid"),
    #SVC(),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=100),
    MLPClassifier(alpha=0.01,hidden_layer_sizes=[32, 16, 8]),
    AdaBoostClassifier(DecisionTreeClassifier(max_depth=5), n_estimators=100),
    GaussianNB(),
    LinearDiscriminantAnalysis(),
    QuadraticDiscriminantAnalysis() 
    ]

# %%
X = chois_short
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = chois_short_other
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99567;   0.98658;   0.97660;   0.99674;   0.98356;   0.99477;   0.97407
# Linear SVM          0.91058;   0.91533;   0.91410;   0.93326;   0.93808;   0.89592;   0.91636
# Poly SVM            0.91810;   0.92125;   0.91840;   0.93872;   0.94121;   0.90564;   0.92126
# sigmoid SVM         0.46283;   0.45883;   0.52640;   0.59702;   0.65541;   0.39610;   0.44828
# RBF SVM             0.91194;   0.91700;   0.91470;   0.93416;   0.93861;   0.89829;   0.91594
# Decision Tree       0.93092;   0.93200;   0.95430;   0.94867;   0.96785;   0.91653;   0.94765
# Random Forest       0.95392;   0.95100;   0.96040;   0.96585;   0.97258;   0.94101;   0.94331
# Neural Net          0.93367;   0.93450;   0.92790;   0.94853;   0.94730;   0.94076;   0.94333
# AdaBoost            1.00000;   0.98908;   0.98490;   1.00000;   0.98939;   1.00000;   0.98450
# Naive Bayes         0.73600;   0.73875;   0.72520;   0.76385;   0.76919;   0.78215;   0.78820
# LDA                 0.90163;   0.90567;   0.90480;   0.92565;   0.93065;   0.89206;   0.91257
# QDA                 0.82044;   0.81750;   0.77910;   0.85036;   0.82167;   0.84654;   0.82898

# %%
X = chois_long
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = chois_long_other
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99454;   0.98483;   0.96480;   0.99590;   0.97520;   0.99372;   0.96171
# Linear SVM          0.92354;   0.92492;   0.93020;   0.94264;   0.94986;   0.91300;   0.93350
# Poly SVM            0.95400;   0.95325;   0.95620;   0.96533;   0.96889;   0.94944;   0.95716
# Decision Tree       0.92729;   0.92833;   0.90460;   0.94304;   0.92928;   0.93809;   0.92482
# Random Forest       0.95583;   0.95108;   0.96540;   0.96723;   0.97600;   0.94380;   0.95070
# Neural Net          0.97262;   0.96658;   0.97290;   0.97946;   0.98095;   0.96808;   0.96980
# AdaBoost            1.00000;   0.99108;   0.98440;   1.00000;   0.98908;   1.00000;   0.98058
# Naive Bayes         0.70952;   0.70992;   0.68650;   0.73420;   0.72732;   0.76171;   0.76226
# LDA                 0.90125;   0.90150;   0.91600;   0.92583;   0.93918;   0.88857;   0.92188
# QDA                 0.86608;   0.86192;   0.83710;   0.89190;   0.87314;   0.88335;   0.87620

# %%
from sklearn.decomposition import PCA

pca_long = PCA()
pca_long.fit(chois_long)
chois_long_PCA = pca_long.transform(chois_long)
chois_long_other_PCA = pca_long.transform(chois_long_other)
print(pca_long.explained_variance_ratio_)

pca_short = PCA()
pca_short.fit(chois_short)
chois_short_PCA = pca_short.transform(chois_short)
chois_short_other_PCA = pca_short.transform(chois_short_other)
print(pca_short.explained_variance_ratio_)
# Out:
# [2.33431094e-01 1.91305793e-01 8.93553493e-02 8.02657780e-02
#  5.96972037e-02 5.33855739e-02 4.18902080e-02 3.83459251e-02
#  3.71856999e-02 2.71309526e-02 2.23234739e-02 1.72686241e-02
#  1.66897891e-02 1.29961782e-02 1.18350523e-02 1.09236755e-02
#  1.05665043e-02 8.84135672e-03 7.50598985e-03 7.00932609e-03
#  6.41852851e-03 4.69165024e-03 4.01042258e-03 3.76212795e-03
#  2.86704925e-03 2.85483952e-04 1.11899017e-05 8.99136859e-29]
# [5.05577828e-01 1.41038434e-01 8.10465257e-02 6.43909599e-02
#  4.10152749e-02 2.91088501e-02 2.37120620e-02 2.28822736e-02
#  2.03512677e-02 1.86516610e-02 1.74760953e-02 1.48506952e-02
#  1.07796893e-02 8.67942135e-03 4.38961607e-04]

# %%
X = chois_short_PCA
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = chois_short_other_PCA
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))

# %%
X = chois_long_PCA
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = chois_long_other_PCA
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))

# %%
X = chois_short_PCA[:, pca_short.explained_variance_ratio_ >0.01]
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = chois_short_other_PCA[:, pca_short.explained_variance_ratio_ >0.01]
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))

# %%
X = chois_long_PCA[:, pca_long.explained_variance_ratio_ >0.01]
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = chois_long_other_PCA[:, pca_long.explained_variance_ratio_ >0.01]
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99400;   0.98392;   0.96130;   0.99549;   0.97270;   0.99301;   0.95822
# Linear SVM          0.91027;   0.91533;   0.90950;   0.93234;   0.93467;   0.90064;   0.91177
# Poly SVM            0.95942;   0.95542;   0.95570;   0.96938;   0.96858;   0.95601;   0.95534
# RBF SVM             0.96483;   0.96117;   0.96050;   0.97346;   0.97192;   0.96222;   0.96301
# Decision Tree       0.90617;   0.90592;   0.87390;   0.92973;   0.91107;   0.89264;   0.85106
# Random Forest       0.90665;   0.90400;   0.90410;   0.93310;   0.93546;   0.87093;   0.85237
# Neural Net          0.98790;   0.97983;   0.97380;   0.99094;   0.98170;   0.98398;   0.96623
# AdaBoost            1.00000;   0.98017;   0.96410;   1.00000;   0.97473;   1.00000;   0.96007
# Naive Bayes         0.77254;   0.76567;   0.71740;   0.81853;   0.77692;   0.77302;   0.73867
# LDA                 0.87908;   0.88267;   0.90340;   0.90819;   0.92964;   0.86901;   0.91075
# QDA                 0.88725;   0.88833;   0.87820;   0.91134;   0.90868;   0.89497;   0.90046

# %%
data = loadmat(pd+'V_norm_15.mat')
vPCA = np.array(data['V'])
X = np.matmul(chois_long,vPCA)
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = np.matmul(chois_long_other,vPCA)
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99410;   0.98325;   0.97170;   0.99557;   0.98010;   0.99313;   0.96864
# Linear SVM          0.66485;   0.66608;   0.71420;   0.79869;   0.83327;   0.50000;   0.50000
# Poly SVM            0.66504;   0.66642;   0.71420;   0.79878;   0.83327;   0.50028;   0.50000
# RBF SVM             0.66485;   0.66608;   0.71420;   0.79869;   0.83327;   0.50000;   0.50000
# Decision Tree       0.80152;   0.80125;   0.81070;   0.84248;   0.86059;   0.80308;   0.80514
# Random Forest       0.87733;   0.88150;   0.91880;   0.91207;   0.94497;   0.83820;   0.87578
# Neural Net          0.94660;   0.94558;   0.95050;   0.95977;   0.96507;   0.94101;   0.94530
# AdaBoost            1.00000;   0.98142;   0.97430;   1.00000;   0.98201;   1.00000;   0.96847
# Naive Bayes         0.60173;   0.60275;   0.53970;   0.60908;   0.55855;   0.66816;   0.63861
# LDA                 0.67560;   0.67775;   0.70880;   0.79096;   0.81738;   0.55388;   0.55614
# QDA                 0.65400;   0.65000;   0.60890;   0.66781;   0.63608;   0.71838;   0.70657

# %%
data = loadmat(pd+'V_super_15.mat')
vPCA = np.array(data['V'])
X = np.matmul(chois_long,vPCA)
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = np.matmul(chois_long_other,vPCA)
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99394;   0.98367;   0.96020;   0.99544;   0.97193;   0.99297;   0.95671
# Linear SVM          0.88485;   0.88908;   0.89440;   0.91305;   0.92336;   0.87281;   0.89721
# Poly SVM            0.92063;   0.92142;   0.93810;   0.94011;   0.95593;   0.91255;   0.93673
# Decision Tree       0.88254;   0.87942;   0.89030;   0.91318;   0.92262;   0.85962;   0.87126
# Random Forest       0.87762;   0.87608;   0.88840;   0.91421;   0.92569;   0.82689;   0.82480
# Neural Net          0.96592;   0.95833;   0.95940;   0.97441;   0.97130;   0.96087;   0.95751
# AdaBoost            1.00000;   0.97767;   0.96010;   1.00000;   0.97188;   1.00000;   0.95601
# Naive Bayes         0.74833;   0.74625;   0.67520;   0.79774;   0.73743;   0.74924;   0.70262
# LDA                 0.87381;   0.87783;   0.89910;   0.90473;   0.92679;   0.86034;   0.90271
# QDA                 0.87862;   0.88125;   0.87570;   0.90524;   0.90693;   0.88189;   0.89650

# %%
data = loadmat(pd+'V_supernorm_15.mat')
vPCA = np.array(data['V'])
X = np.matmul(chois_long,vPCA)
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = np.matmul(chois_long_other,vPCA)
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99396;   0.98367;   0.96020;   0.99546;   0.97193;   0.99299;   0.95671
# Linear SVM          0.88452;   0.88883;   0.89450;   0.91280;   0.92345;   0.87246;   0.89718
# Poly SVM            0.92019;   0.92042;   0.93730;   0.93980;   0.95535;   0.91194;   0.93596
# Decision Tree       0.89138;   0.89000;   0.87900;   0.91904;   0.91392;   0.87369;   0.86376
# Random Forest       0.87294;   0.87383;   0.89020;   0.91110;   0.92691;   0.82059;   0.82680
# Neural Net          0.96788;   0.96258;   0.95510;   0.97595;   0.96855;   0.96177;   0.94537
# AdaBoost            1.00000;   0.97767;   0.95550;   1.00000;   0.96854;   1.00000;   0.95269
# Naive Bayes         0.75229;   0.75067;   0.68760;   0.80172;   0.75024;   0.75183;   0.71056
# LDA                 0.87346;   0.87750;   0.89930;   0.90446;   0.92694;   0.85994;   0.90295
# QDA                 0.87858;   0.88167;   0.87540;   0.90520;   0.90668;   0.88185;   0.89629

# %%
data = loadmat(pd+'V_norm_10.mat')
vPCA = np.array(data['V'])
X = np.matmul(chois_long,vPCA)
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = np.matmul(chois_long_other,vPCA)
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99085;   0.97717;   0.96140;   0.99312;   0.97292;   0.98989;   0.95430
# Linear SVM          0.66485;   0.66608;   0.71420;   0.79869;   0.83327;   0.50000;   0.50000
# Poly SVM            0.66485;   0.66608;   0.71420;   0.79869;   0.83327;   0.50000;   0.50000
# Decision Tree       0.77567;   0.77792;   0.84400;   0.83206;   0.88738;   0.74604;   0.83160
# Random Forest       0.85927;   0.85933;   0.90050;   0.89797;   0.93134;   0.82376;   0.86727
# Neural Net          0.88135;   0.88192;   0.88850;   0.91001;   0.91877;   0.87105;   0.89266
# AdaBoost            1.00000;   0.97942;   0.96890;   1.00000;   0.97828;   1.00000;   0.96018
# Naive Bayes         0.59631;   0.59842;   0.54980;   0.60094;   0.56894;   0.66475;   0.65009
# LDA                 0.65590;   0.65850;   0.71160;   0.78463;   0.82324;   0.51476;   0.54016
# QDA                 0.62425;   0.62242;   0.57690;   0.63021;   0.59678;   0.69442;   0.68071

# %%
data = loadmat(pd+'V_super_10.mat')
vPCA = np.array(data['V'])
X = np.matmul(chois_long,vPCA)
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = np.matmul(chois_long_other,vPCA)
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99304;   0.98250;   0.95960;   0.99477;   0.97152;   0.99185;   0.95566
# Linear SVM          0.86298;   0.86242;   0.90210;   0.89750;   0.92957;   0.84364;   0.90019
# Poly SVM            0.90463;   0.90250;   0.93130;   0.92876;   0.95120;   0.88962;   0.92661
# Decision Tree       0.87973;   0.87750;   0.87380;   0.91268;   0.91174;   0.84742;   0.84470
# Random Forest       0.88471;   0.88250;   0.89500;   0.91865;   0.92991;   0.83825;   0.83488
# Neural Net          0.94663;   0.94725;   0.95280;   0.96067;   0.96696;   0.92999;   0.94219
# AdaBoost            1.00000;   0.97383;   0.95350;   1.00000;   0.96705;   1.00000;   0.95202
# Naive Bayes         0.81556;   0.81492;   0.80410;   0.86600;   0.86030;   0.77578;   0.77376
# LDA                 0.85958;   0.86117;   0.90690;   0.89543;   0.93329;   0.83760;   0.90324
# QDA                 0.88021;   0.88442;   0.89550;   0.91019;   0.92501;   0.86409;   0.89032

# %%
data = loadmat(v'V_supernorm_10.mat')
vPCA = np.array(data['V'])
X = np.matmul(chois_long,vPCA)
y = answers_reg

X_train, X_test, y_train, y_test = \
    train_test_split(X, y, test_size=.2, random_state=777)

X_other = np.matmul(chois_long_other,vPCA)
y_other = answers_other

for name, clf in zip(names, classifiers):
    clf.fit(X_train, y_train)
    score0 = clf.score(X_train, y_train)
    score = clf.score(X_test, y_test)
    score_other = clf.score(X_other, y_other)
    y_t = clf.predict(X_train)
    y_p = clf.predict(X_other)
       
    f1_t = metrics.f1_score(y_train, y_t)
    f1_p = metrics.f1_score(y_other, y_p)
    auc_t = metrics.roc_auc_score(y_train, y_t)
    auc_p = metrics.roc_auc_score(y_other, y_p)
    
    print((name+"   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f};   {:.5f}").format(score0, score, score_other, f1_t, f1_p, auc_t, auc_p))
# Out:
# Nearest Neighbors   0.99310;   0.98242;   0.95940;   0.99482;   0.97138;   0.99195;   0.95542
# Linear SVM          0.86379;   0.86258;   0.90290;   0.89822;   0.93021;   0.84403;   0.90054
# Poly SVM            0.90760;   0.90425;   0.93380;   0.93092;   0.95302;   0.89341;   0.92910
# Decision Tree       0.88298;   0.88050;   0.87390;   0.91200;   0.90952;   0.86870;   0.86376
# Random Forest       0.88744;   0.88583;   0.89580;   0.92049;   0.93037;   0.84190;   0.83670
# Neural Net          0.96825;   0.96117;   0.95690;   0.97623;   0.96943;   0.96207;   0.95692
# AdaBoost            1.00000;   0.97300;   0.95210;   1.00000;   0.96631;   1.00000;   0.94474
# Naive Bayes         0.81569;   0.81508;   0.80310;   0.86611;   0.85967;   0.77588;   0.77212
# LDA                 0.85985;   0.86200;   0.90780;   0.89574;   0.93400;   0.83739;   0.90355
# QDA                 0.87913;   0.88208;   0.89660;   0.90943;   0.92584;   0.86256;   0.89130
